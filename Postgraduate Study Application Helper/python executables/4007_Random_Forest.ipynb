# %% [markdown]
# # Data preparing

# %%
import pandas as pd
import numpy as np

# %%
#input data
dataset = pd.read_csv("application data.csv")
dataset.head()
# Out:
#                       applied subject  year until now   GPA
# 0  Engineering - Civil and Structural               2  3.72  \
# 1                    Modern Languages               5  2.48
# 2                          Geophysics              10  3.32
# 3     Business and Management Studies              10  3.65
# 4     English Language and Literature               5  3.86
#
#                             current subject  is honor college    GMAT     GRE
# 0        Engineering - Civil and Structural                 1  796.09  305.28  \
# 1  Theology, Divinity and Religious Studies                 0    0.00  192.80
# 2                                Geophysics                 1    0.00  308.70
# 3                        Materials Sciences                 1  763.28    0.00
# 4  Computer Science and Information Systems                 1    0.00  328.85
#
#    english test exempted  TOFEL  IELTS  internship  result
# 0                      0    0.0   8.14           1       0
# 1                      1    0.0   0.00           1       1
# 2                      0    0.0   7.38           1       1
# 3                      1    0.0   0.00           1       0
# 4                      0    0.0   6.40           1       1

# %%
# display the shape of the dataset
dataset.shape
# Out:
# (25000, 12)

# %%
dataset.describe()
# Out:
#        year until now           GPA  is honor college          GMAT  \
# count    25000.000000  25000.000000      25000.000000  25000.000000
# mean         5.006360      3.285474          0.651760    338.318789
# std          3.161531      0.483219          0.476422    352.990901
# min          0.000000      2.000000          0.000000      0.000000
# 25%          2.000000      3.060000          0.000000      0.000000
# 50%          5.000000      3.330000          1.000000      0.000000
# 75%          8.000000      3.660000          1.000000    733.020000
# max         10.000000      4.000000          1.000000    799.980000
#
#                 GRE  english test exempted         TOFEL         IELTS  \
# count  25000.000000           25000.000000  25000.000000  25000.000000
# mean     196.238197               0.504400     25.022915      2.322859
# std      145.730378               0.499991     43.646477      3.501595
# min        0.000000               0.000000      0.000000      0.000000
# 25%        0.000000               0.000000      0.000000      0.000000
# 50%      279.870000               1.000000      0.000000      0.000000
# 75%      320.080000               1.000000     80.085000      6.580000
# max      340.000000               1.000000    120.000000      9.000000
#
#          internship        result
# count  25000.000000  25000.000000
# mean       0.651000      0.645440
# std        0.476663      0.478389
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        1.000000      1.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
#check missing value
dataset.isnull().sum()
# Out:
# applied subject          0
# year until now           0
# GPA                      0
# current subject          0
# is honor college         0
# GMAT                     0
# GRE                      0
# english test exempted    0
# TOFEL                    0
# IELTS                    0
# internship               0
# result                   0
# dtype: int64

# %% [markdown]
# # Data processing

# %%
#set target and feature
#y is target (result) that we want to predict
y = dataset['result']
#x is feature that we remove the result column
x_oldest = dataset.drop(labels=['result'], axis=1)

# %%
x_oldest.head()
# Out:
#                       applied subject  year until now   GPA
# 0  Engineering - Civil and Structural               2  3.72  \
# 1                    Modern Languages               5  2.48
# 2                          Geophysics              10  3.32
# 3     Business and Management Studies              10  3.65
# 4     English Language and Literature               5  3.86
#
#                             current subject  is honor college    GMAT     GRE
# 0        Engineering - Civil and Structural                 1  796.09  305.28  \
# 1  Theology, Divinity and Religious Studies                 0    0.00  192.80
# 2                                Geophysics                 1    0.00  308.70
# 3                        Materials Sciences                 1  763.28    0.00
# 4  Computer Science and Information Systems                 1    0.00  328.85
#
#    english test exempted  TOFEL  IELTS  internship
# 0                      0    0.0   8.14           1
# 1                      1    0.0   0.00           1
# 2                      0    0.0   7.38           1
# 3                      1    0.0   0.00           1
# 4                      0    0.0   6.40           1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: result, dtype: int64

# %%
# Transform categorical data
import category_encoders as ce

# %%
# applied subject and current subject is category column, convert it to count encoding
count_encoder = ce.CountEncoder(cols=["applied subject", "current subject"])

# x is the dataset with category column converted
x = count_encoder.fit_transform(x_oldest)
x
# Out:
#        applied subject  year until now   GPA  current subject
# 0                  429               2  3.72              430  \
# 1                  421               5  2.48              416
# 2                  405              10  3.32              397
# 3                  471              10  3.65              410
# 4                  413               5  3.86              402
# ...                ...             ...   ...              ...
# 24995              421               9  3.02              424
# 24996              410               7  3.31              457
# 24997              420               9  3.23              410
# 24998              420               1  3.85              428
# 24999              435               1  3.62              429
#
#        is honor college    GMAT     GRE  english test exempted   TOFEL  IELTS
# 0                     1  796.09  305.28                      0    0.00   8.14  \
# 1                     0    0.00  192.80                      1    0.00   0.00
# 2                     1    0.00  308.70                      0    0.00   7.38
# 3                     1  763.28    0.00                      1    0.00   0.00
# 4                     1    0.00  328.85                      0    0.00   6.40
# ...                 ...     ...     ...                    ...     ...    ...
# 24995                 1    0.00  326.89                      0    0.00   7.08
# 24996                 1    0.00  338.98                      0  111.04   0.00
# 24997                 1    0.00  336.70                      1    0.00   0.00
# 24998                 1    0.00  316.20                      1    0.00   0.00
# 24999                 1  786.26    0.00                      0    0.00   7.71
#
#        internship
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 24995           0
# 24996           1
# 24997           1
# 24998           0
# 24999           0
#
# [25000 rows x 11 columns]

# %%
# a different encoding approach
one_hot_encoder = ce.OneHotEncoder(cols=["applied subject", "current subject"])
x = one_hot_encoder.fit_transform(x_oldest)
x
# Out:
#        applied subject_1  applied subject_2  applied subject_3
# 0                      1                  0                  0  \
# 1                      0                  1                  0
# 2                      0                  0                  1
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 24995                  0                  1                  0
# 24996                  0                  0                  0
# 24997                  0                  0                  0
# 24998                  0                  0                  0
# 24999                  0                  0                  0
#
#        applied subject_4  applied subject_5  applied subject_6
# 0                      0                  0                  0  \
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      1                  0                  0
# 4                      0                  1                  0
# ...                  ...                ...                ...
# 24995                  0                  0                  0
# 24996                  0                  0                  0
# 24997                  0                  0                  0
# 24998                  0                  0                  0
# 24999                  0                  0                  0
#
#        applied subject_7  applied subject_8  applied subject_9
# 0                      0                  0                  0  \
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 24995                  0                  0                  0
# 24996                  0                  0                  0
# 24997                  1                  0                  0
# 24998                  0                  0                  0
# 24999                  0                  0                  0
#
#        applied subject_10  ...  current subject_57  current subject_58
# 0                       0  ...                   0                   0  \
# 1                       0  ...                   0                   0
# 2                       0  ...                   0                   0
# 3                       0  ...                   0                   0
# 4                       0  ...                   0                   0
# ...                   ...  ...                 ...                 ...
# 24995                   0  ...                   0                   0
# 24996                   0  ...                   0                   0
# 24997                   0  ...                   0                   0
# 24998                   0  ...                   0                   0
# 24999                   0  ...                   0                   0
#
#        current subject_59  is honor college    GMAT     GRE
# 0                       0                 1  796.09  305.28  \
# 1                       0                 0    0.00  192.80
# 2                       0                 1    0.00  308.70
# 3                       0                 1  763.28    0.00
# 4                       0                 1    0.00  328.85
# ...                   ...               ...     ...     ...
# 24995                   0                 1    0.00  326.89
# 24996                   0                 1    0.00  338.98
# 24997                   0                 1    0.00  336.70
# 24998                   0                 1    0.00  316.20
# 24999                   0                 1  786.26    0.00
#
#        english test exempted   TOFEL  IELTS  internship
# 0                          0    0.00   8.14           1
# 1                          1    0.00   0.00           1
# 2                          0    0.00   7.38           1
# 3                          1    0.00   0.00           1
# 4                          0    0.00   6.40           1
# ...                      ...     ...    ...         ...
# 24995                      0    0.00   7.08           0
# 24996                      0  111.04   0.00           1
# 24997                      1    0.00   0.00           1
# 24998                      1    0.00   0.00           0
# 24999                      0    0.00   7.71           0
#
# [25000 rows x 127 columns]

# %%
# Scale the data

from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

scaler = StandardScaler()
cols_to_scale = ["GPA", "GMAT", "GRE", "TOFEL", "IELTS"]
x_scaled = x.copy()
x_scaled[cols_to_scale] = scaler.fit_transform(x_scaled[cols_to_scale])

x_scaled
# Out:
#        applied subject_1  applied subject_2  applied subject_3
# 0                      1                  0                  0  \
# 1                      0                  1                  0
# 2                      0                  0                  1
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 24995                  0                  1                  0
# 24996                  0                  0                  0
# 24997                  0                  0                  0
# 24998                  0                  0                  0
# 24999                  0                  0                  0
#
#        applied subject_4  applied subject_5  applied subject_6
# 0                      0                  0                  0  \
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      1                  0                  0
# 4                      0                  1                  0
# ...                  ...                ...                ...
# 24995                  0                  0                  0
# 24996                  0                  0                  0
# 24997                  0                  0                  0
# 24998                  0                  0                  0
# 24999                  0                  0                  0
#
#        applied subject_7  applied subject_8  applied subject_9
# 0                      0                  0                  0  \
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 24995                  0                  0                  0
# 24996                  0                  0                  0
# 24997                  1                  0                  0
# 24998                  0                  0                  0
# 24999                  0                  0                  0
#
#        applied subject_10  ...  current subject_57  current subject_58
# 0                       0  ...                   0                   0  \
# 1                       0  ...                   0                   0
# 2                       0  ...                   0                   0
# 3                       0  ...                   0                   0
# 4                       0  ...                   0                   0
# ...                   ...  ...                 ...                 ...
# 24995                   0  ...                   0                   0
# 24996                   0  ...                   0                   0
# 24997                   0  ...                   0                   0
# 24998                   0  ...                   0                   0
# 24999                   0  ...                   0                   0
#
#        current subject_59  is honor college      GMAT       GRE
# 0                       0                 1  1.283113  0.751219  \
# 1                       0                 0 -0.970448 -0.019544
# 2                       0                 1 -0.970448  0.774654
# 3                       0                 1  1.190235 -1.340696
# 4                       0                 1 -0.970448  0.912731
# ...                   ...               ...       ...       ...
# 24995                   0                 1 -0.970448  0.899300
# 24996                   0                 1 -0.970448  0.982146
# 24997                   0                 1 -0.970448  0.966523
# 24998                   0                 1 -0.970448  0.826047
# 24999                   0                 1  1.255286 -1.340696
#
#        english test exempted     TOFEL     IELTS  internship
# 0                          0 -0.571637  1.635337           1
# 1                          1 -0.571637 -0.675794           1
# 2                          0 -0.571637  1.419555           1
# 3                          1 -0.571637 -0.675794           1
# 4                          0 -0.571637  1.141311           1
# ...                      ...       ...       ...         ...
# 24995                      0 -0.571637  1.334378           0
# 24996                      0  1.969994 -0.675794           1
# 24997                      1 -0.571637 -0.675794           1
# 24998                      1 -0.571637 -0.675794           0
# 24999                      0 -0.571637  1.513250           0
#
# [25000 rows x 127 columns]

# %%
#split dataset into training and testing set
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(x_scaled, y, train_size=0.8, random_state=1)

# %%
print('Training Features Shape:', train_x.shape)
print('Training Labels Shape:', train_y.shape)
print('Testing Features Shape:', test_x.shape)
print('Testing Labels Shape:', test_y.shape)
# Out:
# Training Features Shape: (20000, 127)
# Training Labels Shape: (20000,)
# Testing Features Shape: (5000, 127)
# Testing Labels Shape: (5000,)

# %% [markdown]
# # Random Forest Classifier

# %%
#define the model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
#training model
rf_model = RandomForestClassifier(n_estimators=100, random_state=1)
rf_model.fit(train_x, train_y)

#predict data
test_y_predicted = rf_model.predict(test_x)
print(test_y_predicted)
# Out:
# [0 1 1 ... 1 1 0]

# %%
accuracy = accuracy_score(test_y, test_y_predicted)
print(accuracy)
# Out:
# 0.7866

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(train_x, train_y)

#predict data
test_y_predicted = rf_model.predict(test_x)
print(test_y_predicted)
# Out:
# [0.9  0.19 0.2  ... 0.19 0.21 0.88]

# %%
# Evaluate
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(test_y, test_y_predicted)
print("Mean Squared Error: ", mse)
# Out:
# Mean Squared Error:  0.17397164

# %%
# Save the model
import joblib

joblib.dump(rf_model, 'random_forest_regression_model.joblib')
joblib.dump(one_hot_encoder, 'model_encoder.joblib')
joblib.dump(scaler, 'model_scaler.joblib')
# Out:
# ['model_scaler.joblib']

# %% [markdown]
# # new

# %%
input = ['Performing Arts', 3, 2.2, 'Performing Arts', 0, 0, 220, 0, 75, 0, 0]
fields = ['applied subject', 'year until now', 'GPA', 'current subject', 'is honor college', 'GMAT', 'GRE', 'english test exempted', 'TOFEL', 'IELTS', 'internship']

if not (len(input) == len(fields)):
    raise ValueError("input size doesn't fit field size")
else:
    input = [{fields[i]: input[i] for i in range(len(input))}]

encoder = joblib.load("../static/model_encoder.joblib")
scaler = joblib.load("../static/model_scaler.joblib")
model = joblib.load("../static/random_forest_regression_model.joblib")

x = encoder.transform(input)
cols_to_scale = ["GPA", "GMAT", "GRE", "TOFEL", "IELTS"]
x_scaled = x.copy()
x_scaled[cols_to_scale] = scaler.transform(x_scaled[cols_to_scale])
predicted = model.predict(x_scaled)

# %%
print(predicted)
# Out:
# [0.3]
# Bad pipe message: %s [b'FV{j45K\x00\xcc}\xaf\xa8\xcb|I\xd09\x10 \xaa=m\xf3\x01\xf1/]m\xbb\xd8\xe1]R\xcd\x02\xb8\xc1F\xc3\x9f\xd9\x10}\x8f\xecJ\xf7\xe0\xad\r\xe1\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r']
# Bad pipe message: %s [b'E\x83\x0e\x85\xfc\x12=']
# Bad pipe message: %s [b'\xbaqO!5\xd9?\xa5\x16\xe3e7>\x19R\x7f9\xba\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b']
# Bad pipe message: %s [b"d\x13\x1a'\xd3\x04\xf6\x917\x1a\xe9\xd2\n\xc0E\xb5\xa9\x1a\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00"]
# Bad pipe message: %s [b'\x0c\xc2\xb6\xda\xb9', b'']
# Bad pipe message: %s [b'\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127']
# Bad pipe message: %s [b'.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00']
# Bad pipe message: %s [b'\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02\x02\x04\x02\x05\x02\x06\x02']
# Bad pipe message: %s [b'&\xa6\x94\xf0\xfe\xbc]\xe3\xaf$\x07\xad\x8a\xd8\x08\x9fx\xc5\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00', b'\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a']
# Bad pipe message: %s [b'\xa5\x80\xb3@;A\xf9\xbb\x16\x19z\xfe\x11h>\xbe\x8c\x9c\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002']
# Bad pipe message: %s [b"\xec\xab\xb8\x9d\xf8C\xcfq\xae\xa8L\xe8\x15c\xfc#\x1e?\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x00", b'0\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00']
# Bad pipe message: %s [b"\xfa\x8bX%\xd0\xeeE\x13j\xbe\xeem\xa7[\xdex\xd6\x9e\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00", b'B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0']
# Bad pipe message: %s [b'\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00']
# Bad pipe message: %s [b'\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0']
# Bad pipe message: %s [b'\x01\x00;\x00\x02\x00\x01\x00\xff\x02']
# Bad pipe message: %s [b'']
