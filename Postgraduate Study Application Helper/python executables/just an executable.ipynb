# %%
import matplotlib.pyplot as plt

yes = 165
no = 25

fig, ax = plt.subplots()
ax.pie([yes, no], labels=['yes', 'no'], colors=['green', 'darkred'], startangle=90, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9c3534db40>,
#   <matplotlib.patches.Wedge at 0x7f9c35333850>],
#  [Text(-0.4418648876951282, -1.007350694158778, 'yes'),
#   Text(0.4418647933801477, 1.00735073552915, 'no')],
#  [Text(-0.24101721147006988, -0.5494640149956971, '86.8%'),
#   Text(0.24101716002553508, 0.5494640375613544, '13.2%')])
